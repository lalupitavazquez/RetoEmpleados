# %% [markdown]
# Importa las librerías requeridas.

# %%
from pandas import DataFrame
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sb
from mpl_toolkits.mplot3d import Axes3D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Lee el archivo CSV llamado empleadosRETO.csv y coloca los datos en un frame de Pandas llamado EmpleadosAttrition.

# %%
df1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/empleadosRETO.xlsx')
EmpleadosAttrition = pd.DataFrame(df1)
EmpleadosAttrition
# Out:
#      Age     BusinessTravel              Department DistanceFromHome  \
# 0     50      Travel_Rarely  Research & Development             1 km
# 1     36      Travel_Rarely  Research & Development             6 km
# 2     21      Travel_Rarely                   Sales             7 km
# 3     52      Travel_Rarely  Research & Development             7 km
# 4     33      Travel_Rarely  Research & Development            15 km
# ..   ...                ...                     ...              ...
# 395   33      Travel_Rarely  Research & Development            14 km
# 396   31      Travel_Rarely                   Sales            20 km
# 397   37  Travel_Frequently  Research & Development            11 km
# 398   38      Travel_Rarely  Research & Development             4 km
# 399   33      Travel_Rarely  Research & Development            14 km
#
#      Education EducationField  EmployeeCount  EmployeeNumber  \
# 0            2        Medical              1             997
# ...

# %% [markdown]
# Elimina las columnas que, con alta probabilidad (estimada por ti), no tienen relación alguna con la salida. Hay algunas columnas que contienen información que no ayuda a definir el desgaste de un empleado, tal es caso de las siguientes:
# EmployeeCount: número de empleados, todos tienen un 1
# EmployeeNumber: ID del empleado, el cual es único para cada empleado
# Over18: mayores de edad, todos dicen “Y”
# StandardHours: horas de trabajo, todos tienen “80”

# %%
columnas_a_eliminar = ['EmployeeCount', 'Over18','StandardHours','EmployeeNumber']
EmpleadosAttrition2 = EmpleadosAttrition.drop(columnas_a_eliminar, axis=1)
EmpleadosAttrition2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       400 non-null    int64
#  1   BusinessTravel            396 non-null    object
#  2   Department                400 non-null    object
#  3   DistanceFromHome          400 non-null    object
#  4   Education                 400 non-null    int64
#  5   EducationField            400 non-null    object
#  6   EnvironmentSatisfaction   400 non-null    int64
#  7   Gender                    400 non-null    object
#  8   JobInvolvement            400 non-null    int64
#  9   JobLevel                  400 non-null    int64
#  10  JobRole                   400 non-null    object
#  11  JobSatisfaction           400 non-null    int64
#  12  MaritalStatus             395 non-null    object
#  13  MonthlyIncome             400 non-null    int64
# ...

# %% [markdown]
# Analiza la información proporcionada, si detectaste que no se cuenta con los años que el empelado lleva en la compañía y parece ser un buen dato. Dicha cantidad se puede calcular con la fecha de contratación ‘HiringDate’.

# %%
EmpleadosAttrition2['HiringDate'] = pd.to_datetime(EmpleadosAttrition2['HiringDate'], errors='coerce')
EmpleadosAttrition2['HiringDate']
# Out:
# 0     2013-06-06
# 1     2015-12-25
# 2     2017-02-14
# 3     2010-07-29
# 4     2011-07-10
#          ...
# 395   2013-09-05
# 396   2016-02-04
# 397   2008-01-21
# 398   2018-08-27
# 399   2010-08-02
# Name: HiringDate, Length: 400, dtype: datetime64[ns]

# %%
from datetime import datetime
d=datetime(2023, 1, 1)
EmpleadosAttrition2['Antiguedad']= (EmpleadosAttrition2['HiringDate']-d)
EmpleadosAttrition2['Antiguedad2']=(EmpleadosAttrition2['Antiguedad'].dt.days)/365
EmpleadosAttrition2['Antiguedad2']
# Out:
# 0      -9.578082
# 1      -7.024658
# 2      -5.882192
# 3     -12.435616
# 4     -11.487671
#          ...
# 395    -9.328767
# 396    -6.912329
# 397   -14.956164
# 398    -4.350685
# 399   -12.424658
# Name: Antiguedad2, Length: 400, dtype: float64

# %% [markdown]
# Crea una columna llamada Year y obtén el año de contratación del empleado a partir de su fecha ‘HiringDate’.

# %%
EmpleadosAttrition2['Year'] = pd.DatetimeIndex(EmpleadosAttrition2['HiringDate']).year
EmpleadosAttrition2['Year']
# Out:
# 0      2013.0
# 1      2015.0
# 2      2017.0
# 3      2010.0
# 4      2011.0
#         ...
# 395    2013.0
# 396    2016.0
# 397    2008.0
# 398    2018.0
# 399    2010.0
# Name: Year, Length: 400, dtype: float64

# %% [markdown]
# Crea una columna llamada YearsAtCompany que contenga los años que el empleado lleva en la compañía hasta el año 2018. Para su cálculo, usa la variable Year que acabas de crear.

# %%
EmpleadosAttrition2['YearsAtCompany']=EmpleadosAttrition2['Year']-2018
EmpleadosAttrition2['YearsAtCompany']
# Out:
# 0      -5.0
# 1      -3.0
# 2      -1.0
# 3      -8.0
# 4      -7.0
#        ...
# 395    -5.0
# 396    -2.0
# 397   -10.0
# 398     0.0
# 399    -8.0
# Name: YearsAtCompany, Length: 400, dtype: float64

# %% [markdown]
# La DistanceFromHome está dada en kilómetros, pero tiene las letras “km” al final y así no puede ser entera.
#
# Renombra la variable DistanceFromHome a DistanceFromHome_km.
#
# Crea una nueva variable DistanceFromHome que sea entera, es decir, solo con números.

# %%
EmpleadosAttrition2['DistanceFromHome'] = EmpleadosAttrition2['DistanceFromHome'].str.replace('km', '').astype(int)
EmpleadosAttrition2['DistanceFromHome']
# Out:
# 0       1
# 1       6
# 2       7
# 3       7
# 4      15
#        ..
# 395    14
# 396    20
# 397    11
# 398     4
# 399    14
# Name: DistanceFromHome, Length: 400, dtype: int64

# %%
EmpleadosAttrition2 = EmpleadosAttrition2.rename(columns={'DistanceFromHome': 'DistanceFromHome_km'})
EmpleadosAttrition2
# Out:
#      Age     BusinessTravel              Department  DistanceFromHome_km  \
# 0     50      Travel_Rarely  Research & Development                    1
# 1     36      Travel_Rarely  Research & Development                    6
# 2     21      Travel_Rarely                   Sales                    7
# 3     52      Travel_Rarely  Research & Development                    7
# 4     33      Travel_Rarely  Research & Development                   15
# ..   ...                ...                     ...                  ...
# 395   33      Travel_Rarely  Research & Development                   14
# 396   31      Travel_Rarely                   Sales                   20
# 397   37  Travel_Frequently  Research & Development                   11
# 398   38      Travel_Rarely  Research & Development                    4
# 399   33      Travel_Rarely  Research & Development                   14
#
#      Education EducationField  EnvironmentSatisfaction  Gender  \
# ...

# %% [markdown]
# Aprovechando los ajustes que se están haciendo, la empresa desea saber si todos los departamentos tienen un ingreso promedio similar. Genera una nuevo frame llamado SueldoPromedioDepto que contenga el MonthlyIncome promedio por departamento de los empleados y colócalo en una variable llamada SueldoPromedio. Esta tabla solo es informativa, no la vas a utilizar en el set de datos que estás construyendo.

# %%
SueldoPromedioDepto=EmpleadosAttrition2[['MonthlyIncome', 'Department']].groupby('Department').mean()
SueldoPromedioDepto
# Out:
#                         MonthlyIncome
# Department
# Human Resources           6239.888889
# Research & Development    6804.149813
# Sales                     7188.250000

# %% [markdown]
# La variable MonthlyIncome tiene un valor numérico muy grande comparada con las otras variables. Escala dicha variable para que tenga un valor entre 0 y 1.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Crear un objeto MinMaxScaler
scaler = MinMaxScaler()

# Escalar la columna
EmpleadosAttrition2['MonthlyIncome2'] = EmpleadosAttrition2['MonthlyIncome']/EmpleadosAttrition2['MonthlyIncome'].abs().max()
EmpleadosAttrition2['MonthlyIncome2']
# Out:
# 0      0.871126
# 1      0.247384
# 2      0.134131
# 3      0.522956
# 4      0.681420
#          ...
# 395    0.121965
# 396    0.228258
# 397    0.610074
# 398    0.165523
# 399    0.137986
# Name: MonthlyIncome2, Length: 400, dtype: float64

# %% [markdown]
# Todo parece indicar que las variables categóricas que quedan sí son importantes para obtener la variable de salida. Convierte todas las variables categóricas que quedan a numéricas:
#
# a) BusinessTravel
#
# b) Department
#
# c) EducationField
#
# d) Gender
#
# e) JobRole
#
# f) MaritalStatus
#
# g) Attrition

# %%
EmpleadosAttrition3=EmpleadosAttrition2.loc[:,['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Attrition']]

from sklearn.preprocessing import LabelEncoder
le_col1 = LabelEncoder()
le_col2 = LabelEncoder()
le_col3 = LabelEncoder()
le_col4 = LabelEncoder()
le_col5 = LabelEncoder()
le_col6 = LabelEncoder()
le_col7 = LabelEncoder()

EmpleadosAttrition3['BusinessTravel'] = le_col1.fit_transform(EmpleadosAttrition3['BusinessTravel'])
EmpleadosAttrition3['Department'] = le_col2.fit_transform(EmpleadosAttrition3['Department'])
EmpleadosAttrition3['EducationField'] = le_col3.fit_transform(EmpleadosAttrition3['EducationField'])
EmpleadosAttrition3['Gender'] = le_col4.fit_transform(EmpleadosAttrition3['Gender'])
EmpleadosAttrition3['JobRole'] = le_col5.fit_transform(EmpleadosAttrition3['JobRole'])
EmpleadosAttrition3['MaritalStatus'] = le_col6.fit_transform(EmpleadosAttrition3['MaritalStatus'])
EmpleadosAttrition3['Attrition'] = le_col7.fit_transform(EmpleadosAttrition3['Attrition'])
EmpleadosAttrition3
# Out:
#      BusinessTravel  Department  EducationField  Gender  JobRole  \
# 0                 2           1               3       1        5
# 1                 2           1               3       1        4
# 2                 2           2               2       1        8
# 3                 2           1               1       1        0
# 4                 2           1               3       1        3
# ..              ...         ...             ...     ...      ...
# 395               2           1               3       1        2
# 396               2           2               1       0        7
# 397               1           1               4       1        5
# 398               2           1               3       0        2
# 399               2           1               3       0        6
#
#      MaritalStatus  Attrition
# 0                0          0
# 1                0          0
# 2                2          1
# 3                2          0
# ...

# %% [markdown]
# Ahora debes hacer la evaluación de las variables para quedarte con las mejores. Calcula la correlación lineal de cada una de las variables con respecto al Attrition.

# %%
EmpleadosAttrition3.corr()
# Out:
#                 BusinessTravel  Department  EducationField    Gender  \
# BusinessTravel        1.000000   -0.011692       -0.000600 -0.050741
# Department           -0.011692    1.000000        0.022239 -0.044679
# EducationField       -0.000600    0.022239        1.000000 -0.053601
# Gender               -0.050741   -0.044679       -0.053601  1.000000
# JobRole               0.022770    0.643188        0.003297 -0.077855
# MaritalStatus         0.019152    0.092023       -0.060575 -0.110816
# Attrition             0.060677    0.054236        0.051184 -0.028839
#
#                  JobRole  MaritalStatus  Attrition
# BusinessTravel  0.022770       0.019152   0.060677
# Department      0.643188       0.092023   0.054236
# EducationField  0.003297      -0.060575   0.051184
# Gender         -0.077855      -0.110816  -0.028839
# JobRole         1.000000       0.095221   0.078684
# MaritalStatus   0.095221       1.000000   0.187283
# Attrition       0.078684       0.187283   1.000000

# %%
x1=EmpleadosAttrition3['BusinessTravel']
x2=EmpleadosAttrition3['Department']
x3=EmpleadosAttrition3['EducationField'] 
x4=EmpleadosAttrition3['Gender']
x5=EmpleadosAttrition3['JobRole']
x6=EmpleadosAttrition3['MaritalStatus']
x7=EmpleadosAttrition3['Attrition']

correlation_matrix = np.corrcoef([x1, x2, x3, x4, x5,x6,x7])

x7_correlations = correlation_matrix[6, :-1]

# Imprimimos las correlaciones
print(f"La correlación entre x1 y x7 es: {x7_correlations[0]}")
print(f"La correlación entre x2 y x7 es: {x7_correlations[1]}")
print(f"La correlación entre x3 y x7 es: {x7_correlations[2]}")
print(f"La correlación entre x4 y x7 es: {x7_correlations[3]}")
print(f"La correlación entre x5 y x7 es: {x7_correlations[4]}")
print(f"La correlación entre x6 y x7 es: {x7_correlations[5]}")
# Out:
# La correlación entre x1 y x7 es: 0.06067747796951115
# La correlación entre x2 y x7 es: 0.05423584846525848
# La correlación entre x3 y x7 es: 0.051184319893178454
# La correlación entre x4 y x7 es: -0.02883870932201118
# La correlación entre x5 y x7 es: 0.07868359123827778
# La correlación entre x6 y x7 es: 0.1872829315649061

# %% [markdown]
# 15. Selecciona solo aquellas variables que tengan una correlación mayor o igual a 0.1, dejándolas en otro frame llamado EmpleadosAttritionFinal. No olvides mantener la variable de salidaAttrition; esto es equivalente a borrar las que no cumplen con el límite.

# %%
EmpleadosAttritionFinal=EmpleadosAttrition3.loc[:,['MaritalStatus','Attrition']]
EmpleadosAttritionFinal
# Out:
#      MaritalStatus  Attrition
# 0                0          0
# 1                0          0
# 2                2          1
# 3                2          0
# 4                1          1
# ..             ...        ...
# 395              1          1
# 396              1          1
# 397              0          0
# 398              1          0
# 399              1          0
#
# [400 rows x 2 columns]

# %% [markdown]
# 16. Crea una nueva variable llamada EmpleadosAttritionPCA formada por los componentes principales del frame EmpleadosAttritionFinal. Recuerda que el resultado del proceso PCA es un numpy array, por lo que, para hacer referencia a una columna, por ejemplo, la 0, puedes usar la instrucción EmpleadosAttritionPCA[:,0]).

# %%
EmpleadosAttritionPCA=EmpleadosAttritionFinal
EmpleadosAttritionPCA

from sklearn.decomposition import PCA

# Creamos una instancia del modelo PCA y ajustamos los datos
pca = PCA(n_components=2)
pca.fit(EmpleadosAttritionPCA)

# Obtenemos las componentes principales y su varianza explicada
components = pca.components_
variance = pca.explained_variance_ratio_

# Imprimimos los resultados
print(f"Las componentes principales son: {components}")
print(f"La varianza explicada por cada componente es: {variance}")
# Out:
# Las componentes principales son: [[ 0.99278607  0.11989921]
#  [-0.11989921  0.99278607]]
# La varianza explicada por cada componente es: [0.81254897 0.18745103]

# %%
transform=pca.transform(EmpleadosAttritionPCA)
transform
arr_con_nombres = pd.DataFrame(transform.reshape(-1, transform.shape[-1]), columns=['Columna1', 'Columna2'])
arr_con_nombres
# Out:
#      Columna1  Columna2
# 0   -1.074619 -0.036417
# 1   -1.074619 -0.036417
# 2    1.030853  0.716571
# 3    0.910954 -0.276215
# 4    0.038067  0.836470
# ..        ...       ...
# 395  0.038067  0.836470
# 396  0.038067  0.836470
# 397 -1.074619 -0.036417
# 398 -0.081832 -0.156316
# 399 -0.081832 -0.156316
#
# [400 rows x 2 columns]

# %%
df_concat_horizontal = pd.concat([EmpleadosAttritionPCA,arr_con_nombres],ignore_index=True, axis=1)
EmpleadosAttritionPCA2=df_concat_horizontal
EmpleadosAttritionPCA2
# Out:
#      0  1         2         3
# 0    0  0 -1.074619 -0.036417
# 1    0  0 -1.074619 -0.036417
# 2    2  1  1.030853  0.716571
# 3    2  0  0.910954 -0.276215
# 4    1  1  0.038067  0.836470
# ..  .. ..       ...       ...
# 395  1  1  0.038067  0.836470
# 396  1  1  0.038067  0.836470
# 397  0  0 -1.074619 -0.036417
# 398  1  0 -0.081832 -0.156316
# 399  1  0 -0.081832 -0.156316
#
# [400 rows x 4 columns]

# %% [markdown]
# Guarda el set de datos que has formado y que tienes en EmpleadosAttritionFinal en un archivo CSV llamado EmpleadosAttritionFinal.csv. Las últimas columnas que colocaste quedarán después de la variable Attrition, lo cual no importa, pero si gustas lo puedes arreglar antes de escribir el archivo.

# %%
# Guardamos el DataFrame en un archivo CSV llamado "data.csv"
EmpleadosAttritionPCA2.to_csv('EmpleadosAttritionFinal.csv', index=False)
